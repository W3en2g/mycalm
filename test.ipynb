# %%
from model import calm

calm_config = calm.CALMConfig(
    anchor_model="google/gemma-7b",
    aug_model="google/gemma-2b",
    #   connections=[(0,0),(1,1)],  # Each element is a tuple (anchor_model_layer_index, aug_model_layer_index)
    num_connections = 2,
    num_heads=2,
)

model = calm.CALM(calm_config)
# Out:
# ...
# Loading checkpoint shards: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]

# %%
calm_config.save_pretrained('./raw_calm_model')
model.save_pretrained('./raw_calm_model')

# model_path = "/home/pcwen/projects/calm/calm_saves"
# # model_path = "test_here"
# model_path = "./raw_calm_model"
# config = calm.CALMConfig.from_pretrained(model_path)
# loaded_model = calm.CALM.from_pretrained(model_path, config = config,ignore_mismatched_sizes=True)

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b")

prompt = "My name is"

inputs = tokenizer(prompt, return_tensors="pt")

generate_ids = loaded_model.generate(inputs.input_ids, max_length=100)
print(tokenizer.decode(generate_ids[0], skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 8
#       4 prompt = "My name is"
#       6 inputs = tokenizer(prompt, return_tensors="pt")
# ----> 8 generate_ids = loaded_model.generate(inputs.input_ids, max_length=100)
#       9 print(tokenizer.decode(generate_ids[0], skip_special_tokens=True))
#
# File ~/miniconda3/envs/calm/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# ...
